# %%
import pandas as pd
dff = pd.read_excel(r"C:\Users\DPQW8400\PycharmProjects\untitled\abc.xlsx")
print(dff)
# Out:
#          Date  Temperature  WindSpeed  Event
# 0  01-08-2018         78.0        6.0   Rain
# 1  07-04-2019          NaN        7.0  Sunny
# 2  05-08-2019         29.0        2.0   Snow
# 3  10-09-2019          1.0        7.0    Fog
# 4  28-10-2019          8.0        4.0   Rain
# 5   4-11-2019          NaN        NaN   Smog
# 6   5-11-2019         10.0        5.0  Sunny
# 7   6-11-2019          NaN        NaN    NaN
# 8   8-11-2019         14.0        7.0   wind

# %%
print(dff['Date'][dff['Event']=='Rain'])
# Out:
# 0    01-08-2018
# 4    28-10-2019
# Name: Date, dtype: object

# %%
df
# Out:
#          Date  Temperature  WindSpeed  Event
# 0  01-08-2018           78          6   Rain
# 1  07-04-2019           38          7  Sunny
# 2  05-08-2019           29          2   Snow
# 3  10-09-2019            1          7    Fog
# 4  28-10-2019            8          4   Rain

# %%
print(df['Date'][df['Temperature']>29])
# Out:
# 0    01-08-2018
# 1    07-04-2019
# Name: Date, dtype: object

# %%
df[1:2]
# Out:
#          Date  Temperature  WindSpeed  Event
# 1  07-04-2019           38          7  Sunny

# %%
df.Temperature.mean()
# Out:
# 30.8

# %%
type(df['WindSpeed'])
# Out:
# pandas.core.series.Series

# %%
df.describe()
# Out:
#        Temperature  WindSpeed
# count     5.000000   5.000000
# mean     30.800000   5.200000
# std      30.375977   2.167948
# min       1.000000   2.000000
# 25%       8.000000   4.000000
# 50%      29.000000   6.000000
# 75%      38.000000   7.000000
# max      78.000000   7.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df
# Out:
#          Date  Temperature  WindSpeed  Event
# 0  01-08-2018           78          6   Rain
# 1  07-04-2019           38          7  Sunny
# 2  05-08-2019           29          2   Snow
# 3  10-09-2019            1          7    Fog
# 4  28-10-2019            8          4   Rain

# %%
df.fillna({'Temperature':'abc','WindSpeed':9})
# Out:
#          Date Temperature  WindSpeed  Event
# 0  01-08-2018          78        6.0   Rain
# 1  07-04-2019          38        7.0  Sunny
# 2  05-08-2019          29        2.0   Snow
# 3  10-09-2019           1        7.0    Fog
# 4  28-10-2019           8        4.0   Rain
# 5   4-11-2019         abc        9.0   Smog

# %%
df.fillna(method="bfill")
# Out:
#          Date  Temperature  WindSpeed  Event
# 0  01-08-2018         78.0        6.0   Rain
# 1  07-04-2019         38.0        7.0  Sunny
# 2  05-08-2019         29.0        2.0   Snow
# 3  10-09-2019          1.0        7.0    Fog
# 4  28-10-2019          8.0        4.0   Rain
# 5   4-11-2019          NaN        NaN   Smog

# %%
df.interpolate()
# Out:
#          Date  Temperature  WindSpeed  Event
# 0  01-08-2018         78.0        6.0   Rain
# 1  07-04-2019         38.0        7.0  Sunny
# 2  05-08-2019         29.0        2.0   Snow
# 3  10-09-2019          1.0        7.0    Fog
# 4  28-10-2019          8.0        4.0   Rain
# 5   4-11-2019          8.0        4.0   Smog

# %%
df
# Out:
#          Date  Temperature  WindSpeed  Event
# 0  01-08-2018         78.0        6.0   Rain
# 1  07-04-2019          NaN        7.0  Sunny
# 2  05-08-2019         29.0        2.0   Snow
# 3  10-09-2019          1.0        7.0    Fog
# 4  28-10-2019          8.0        4.0   Rain
# 5   4-11-2019          NaN        NaN   Smog
# 6   5-11-2019         10.0        5.0  Sunny
# 7   6-11-2019          NaN        NaN    NaN
# 8   8-11-2019         14.0        7.0   wind

# %%
df
# Out:
#          Date  Temperature  WindSpeed  Event
# 0  01-08-2018         78.0        6.0   Rain
# 1  07-04-2019          NaN        7.0  Sunny
# 2  05-08-2019         29.0        2.0   Snow
# 3  10-09-2019          1.0        7.0    Fog
# 4  28-10-2019          8.0        4.0   Rain
# 5   4-11-2019          NaN        NaN   Smog
# 6   5-11-2019         10.0        5.0  Sunny
# 7   6-11-2019          NaN        NaN    NaN
# 8   8-11-2019         14.0        7.0   wind

# %%
df.interpolate()
# Out:
#          Date  Temperature  WindSpeed  Event
# 0  01-08-2018         78.0        6.0   Rain
# 1  07-04-2019         53.5        7.0  Sunny
# 2  05-08-2019         29.0        2.0   Snow
# 3  10-09-2019          1.0        7.0    Fog
# 4  28-10-2019          8.0        4.0   Rain
# 5   4-11-2019          9.0        4.5   Smog
# 6   5-11-2019         10.0        5.0  Sunny
# 7   6-11-2019         12.0        6.0    NaN
# 8   8-11-2019         14.0        7.0   wind

# %%
df.interpolate(method=time)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-e265dff87a16> in <module>
# ----> 1 df.interpolate(method=time)
#
# NameError: name 'time' is not defined

# %%
df.fillna(method="ffill")
# Out:
#          Date  Temperature  WindSpeed  Event
# 0  01-08-2018         78.0        6.0   Rain
# 1  07-04-2019         78.0        7.0  Sunny
# 2  05-08-2019         29.0        2.0   Snow
# 3  10-09-2019          1.0        7.0    Fog
# 4  28-10-2019          8.0        4.0   Rain
# 5   4-11-2019          8.0        4.0   Smog
# 6   5-11-2019         10.0        5.0  Sunny
# 7   6-11-2019         10.0        5.0  Sunny
# 8   8-11-2019         14.0        7.0   wind

# %%
df.interpolate()
# Out:
#          Date  Temperature  WindSpeed  Event
# 0  01-08-2018         78.0        6.0   Rain
# 1  07-04-2019         53.5        7.0  Sunny
# 2  05-08-2019         29.0        2.0   Snow
# 3  10-09-2019          1.0        7.0    Fog
# 4  28-10-2019          8.0        4.0   Rain
# 5   4-11-2019          9.0        4.5   Smog
# 6   5-11-2019         10.0        5.0  Sunny
# 7   6-11-2019         12.0        6.0    NaN
# 8   8-11-2019         14.0        7.0   wind

# %%
dt = pd.date_range("08-01-2018","11-9-2019")
idx = pd.DatetimeIndex(dt)
df.reindex(idx)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-e81fa326977f> in <module>
#       2 idx = pd.DatetimeIndex(dt)
#       3 df.reindex(idx)
# ----> 4 df.df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'df'

# %%
df.fillna(0)
# Out:
#             Date  Temperature  WindSpeed  Event
# 2018-08-01     0          0.0        0.0      0
# 2018-08-02     0          0.0        0.0      0
# 2018-08-03     0          0.0        0.0      0
# 2018-08-04     0          0.0        0.0      0
# 2018-08-05     0          0.0        0.0      0
# ...          ...          ...        ...    ...
# 2019-11-05     0          0.0        0.0      0
# 2019-11-06     0          0.0        0.0      0
# 2019-11-07     0          0.0        0.0      0
# 2019-11-08     0          0.0        0.0      0
# 2019-11-09     0          0.0        0.0      0
#
# [466 rows x 4 columns]

# %%
dff.pivot(index='Temperature', columns = 'Event')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-175-816fdfa17ce4> in <module>
# ----> 1 dff.pivot(index='Temperature', columns = 'Event')
#
# NameError: name 'dff' is not defined

# %%
df
# Out:
#            Date  Temperature  WindSpeed Event
# 2018-08-01  NaN          NaN        NaN   NaN
# 2018-08-02  NaN          NaN        NaN   NaN
# 2018-08-03  NaN          NaN        NaN   NaN
# 2018-08-04  NaN          NaN        NaN   NaN
# 2018-08-05  NaN          NaN        NaN   NaN
# ...         ...          ...        ...   ...
# 2019-11-05  NaN          NaN        NaN   NaN
# 2019-11-06  NaN          NaN        NaN   NaN
# 2019-11-07  NaN          NaN        NaN   NaN
# 2019-11-08  NaN          NaN        NaN   NaN
# 2019-11-09  NaN          NaN        NaN   NaN
#
# [466 rows x 4 columns]

# %%
dff.describe
# Out:
# <bound method NDFrame.describe of          Date  Temperature  WindSpeed  Event
# 0  01-08-2018         78.0        6.0   Rain
# 1  07-04-2019          NaN        7.0  Sunny
# 2  05-08-2019         29.0        2.0   Snow
# 3  10-09-2019          1.0        7.0    Fog
# 4  28-10-2019          8.0        4.0   Rain
# 5   4-11-2019          NaN        NaN   Smog
# 6   5-11-2019         10.0        5.0  Sunny
# 7   6-11-2019          NaN        NaN    NaN
# 8   8-11-2019         14.0        7.0   wind>

# %%
dff.describe()
# Out:
#        Temperature  WindSpeed
# count     6.000000   7.000000
# mean     23.333333   5.428571
# std      28.352543   1.902379
# min       1.000000   2.000000
# 25%       8.500000   4.500000
# 50%      12.000000   6.000000
# 75%      25.250000   7.000000
# max      78.000000   7.000000

# %%
import pandas as pd
frame = pd.read_excel(r"C:\Users\DPQW8400\Desktop\SRF2 report Dashboard report V6 MRC_ 23h OCT 2019.xlsx","SRF2 raw data")
frame.shape
# Out:
# (4653, 134)

# %%
import pandas as pd
import numpy as np
data = pd.read_excel(r"C:\Users\DPQW8400\PycharmProjects\untitled\abc.xlsx")
g = data.groupby('Event')
g
g.describe()
# %matplotlib inline
g.plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1085: UserWarning: Attempting to set identical left == right == 3.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1085: UserWarning: Attempting to set identical left == right == 5.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1085: UserWarning: Attempting to set identical left == right == 2.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1085: UserWarning: Attempting to set identical left == right == 8.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# Event
# ...

# %%
data.fillna(method="ffill",inplace=True)
data
# Out:
#          Date Temperature  WindSpeed  Event
# 0  01-08-2018      78   c        6.0   Rain
# 1  07-04-2019      78   c        7.0  Sunny
# 2  05-08-2019      29   C        2.0   Snow
# 3  10-09-2019           1        7.0    Fog
# 4  28-10-2019           8        4.0   Rain
# 5   4-11-2019           8        4.0   Smog
# 6   5-11-2019          10        5.0  Sunny
# 7   6-11-2019          10        5.0  Sunny
# 8   8-11-2019          14        7.0   wind

# %%
data
# Out:
#          Date  Temperature  WindSpeed  Event
# 0  01-08-2018         78.0        6.0   Rain
# 1  07-04-2019         78.0        7.0  Sunny
# 2  05-08-2019         29.0        2.0   Snow
# 3  10-09-2019          1.0        7.0    Fog
# 4  28-10-2019          8.0        4.0   Rain
# 5   4-11-2019          8.0        4.0   Smog
# 6   5-11-2019         10.0        5.0  Sunny
# 7   6-11-2019         10.0        5.0  Sunny
# 8   8-11-2019         14.0        7.0   wind

# %%
import pandas as pd

india_weather = pd.DataFrame({
    'city' : ["mumbai","gurgaon","banglore"],
    'temperature':[33, 45, 25],
    'humidity':[80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           33        80
# 1   gurgaon           45        60
# 2  banglore           25        78

# %%
us_weather = pd.DataFrame({
    'city' : ["new york","chicago","orlando"],
    'temperature':[21, 14, 45],
    'humidity':[68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           45        75

# %%
df = pd.concat([india_weather, us_weather], keys= ["india", "us"])
df
# Out:
#              city  temperature  humidity
# india 0    mumbai           33        80
#       1   gurgaon           45        60
#       2  banglore           25        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           45        75

# %%
df.loc["india"]
# Out:
#        city  temperature  humidity
# 0    mumbai           33        80
# 1   gurgaon           45        60
# 2  banglore           25        78

# %%
import pandas as pd

temperature_df = pd.DataFrame({
    'city' : ["mumbai","gurgaon","banglore"],
    'temperature':[33, 45, 25]
}, index=[0,1,2])
windspeed_df = pd.DataFrame({
    'city' : ["banglore","mumbai"],
    'windspeed':[25, 30]
     
}, index=[2,0])
#df1 = pd.concat([temperature_df,windspeed_df], sort=True)
#df1 = pd.concat([temperature_df,windspeed_df], sort=True,  axis=1)
df11 = pd.concat([temperature_df,windspeed_df], sort=True, axis=1)
df11
# Out:
#        city  temperature      city  windspeed
# 0    mumbai           33    mumbai       30.0
# 1   gurgaon           45       NaN        NaN
# 2  banglore           25  banglore       25.0

# %%
import pandas as pd
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35]
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
df3 = pd.merge(df1, df2, on="city")
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san fransico"],
    "humidity": [65,68,71],
})
df2
# Out:
#            city  humidity
# 0       chicago        65
# 1      new york        68
# 2  san fransico        71

# %%
df3=pd.merge(df1,df2, on="city", how="outer", indicator=True, suffixes=("_first","_second","_third"))
df3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-174-052a7f75f36d> in <module>
# ----> 1 df3=pd.merge(df1,df2, on="city", how="outer", indicator=True, suffixes=("_first","_second","_third"))
#       2 df3
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      81         validate=validate,
#      82     )
# ---> 83     return op.get_result()
#      84
#      85
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     643
#     644         ldata, rdata = self.left._data, self.right._data
# --> 645         lsuf, rsuf = self.suffixes
#     646
#     647         llabels, rlabels = _items_overlap_with_suffix(
#
# ValueError: too many values to unpack (expected 2)

# %%
df3=pd.merge(df1,df2,on="city",how="outer", indicator=True)
df3
# Out:
#            city  temperature  humidity      _merge
# 0      new york         21.0      68.0        both
# 1       chicago         14.0      65.0        both
# 2       orlando         35.0       NaN   left_only
# 3     baltimore         38.0       NaN   left_only
# 4  san fransico          NaN      71.0  right_only

# %%
df3=pd.merge(df1,df2,on="city",how="left")
df3
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %%
df3=pd.merge(df1,df2,on="city",how="left")
df3
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %%
df3=pd.merge(df1,df2,on="city",how="right")
df3
# Out:
#            city  temperature  humidity
# 0      new york         21.0        68
# 1       chicago         14.0        65
# 2  san fransico          NaN        71

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35,38],
    "humidity": [65,68,71, 75]
})
df1
# Out:
#         city  temperature  humidity
# 0   new york           21        65
# 1    chicago           14        68
# 2    orlando           35        71
# 3  baltimore           38        75

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "temperature": [21,14,35],
    "humidity": [65,68,71]
})
df2
# Out:
#         city  temperature  humidity
# 0    chicago           21        65
# 1   new york           14        68
# 2  san diego           35        71

# %%
df3= pd.merge(df1,df2,on="city",how="outer", suffixes=('_first','_second'))
df3
# Out:
#         city  temperature_first  humidity_first  temperature_second  \
# 0   new york               21.0            65.0                14.0
# 1    chicago               14.0            68.0                21.0
# 2    orlando               35.0            71.0                 NaN
# 3  baltimore               38.0            75.0                 NaN
# 4  san diego                NaN             NaN                35.0
#
#    humidity_second
# 0             68.0
# 1             65.0
# 2              NaN
# 3              NaN
# 4             71.0

# %%
import numpy as nm
df3 = df3.pivot(index='city', columns= 'temperature_first')
df3
# Out:
#                   humidity_first                         temperature_second  \
# temperature_first            NaN  14.0  21.0  35.0  38.0                NaN
# city
# baltimore                    NaN   NaN   NaN   NaN  75.0                NaN
# chicago                      NaN  68.0   NaN   NaN   NaN                NaN
# new york                     NaN   NaN  65.0   NaN   NaN                NaN
# orlando                      NaN   NaN   NaN  71.0   NaN                NaN
# san diego                    NaN   NaN   NaN   NaN   NaN               35.0
#
#                                         humidity_second                        \
# temperature_first  14.0  21.0 35.0 38.0             NaN  14.0  21.0 35.0 38.0
# city
# baltimore           NaN   NaN  NaN  NaN             NaN   NaN   NaN  NaN  NaN
# chicago            21.0   NaN  NaN  NaN             NaN  65.0   NaN  NaN  NaN
# new york            NaN  14.0  NaN  NaN             NaN   NaN  68.0  NaN  NaN
# ...

# %%
# import pandas as pd
a = pd.read_excel(r"C:\Users\DPQW8400\PycharmProjects\untitled\abc.xlsx")
a.fillna(method="bfill")
a
# Out:
#          Date  Temperature  WindSpeed  Event
# 0  01-08-2018         78.0        6.0   Rain
# 1  07-04-2019          NaN        7.0  Sunny
# 2  05-08-2019         29.0        2.0   Snow
# 3  10-09-2019          1.0        7.0    Fog
# 4  28-10-2019          8.0        4.0   Rain
# 5   4-11-2019          NaN        NaN   Smog
# 6   5-11-2019         10.0        5.0  Sunny
# 7   6-11-2019          NaN        8.0    NaN
# 8   8-11-2019         14.0        7.0   wind

# %%
a.shape
# Out:
# (9, 4)

# %%
a.Temperature
# Out:
# 0    78   c
# 1       NaN
# 2    29   C
# 3         1
# 4         8
# 5       NaN
# 6        10
# 7       NaN
# 8        14
# Name: Temperature, dtype: object

# %%
a.describe()
# Out:
#        WindSpeed
# count   7.000000
# mean    5.428571
# std     1.902379
# min     2.000000
# 25%     4.500000
# 50%     6.000000
# 75%     7.000000
# max     7.000000

# %%
a.mean()
# Out:
# WindSpeed    5.428571
# dtype: float64

# %%
a.to_csv("b.csv")

# %%
# Out:
#          Date Temperature  WindSpeed  Event
# 0  01-08-2018      78   c        6.0   Rain
# 1  07-04-2019         NaN        7.0  Sunny
# 2  05-08-2019      29   C        2.0   Snow
# 3  10-09-2019           1        7.0    Fog
# 4  28-10-2019           8        4.0   Rain
# 5   4-11-2019         NaN        NaN   Smog
# 6   5-11-2019          10        5.0  Sunny
# 7   6-11-2019         NaN        NaN    NaN
# 8   8-11-2019          14        7.0   wind

# %%
a['Temperature'].mean()
# Out:
# 23.333333333333332

# %%
a['Event']=='Sunny'
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# Name: Event, dtype: bool
